# %% [markdown]
# <div style="background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%); padding: 45px; border-radius: 30px; margin: 20px 0; box-shadow: 0 20px 50px rgba(0,0,0,0.3); font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; color: white; text-align: center;">
#
# <div style="font-size: 55px; margin-bottom: 10px;">🚗 📍 📊</div>
#
# <h1 style="font-size: 42px; font-weight: 800; letter-spacing: 2px; text-transform: uppercase; margin: 10px 0; color: #ffffff; text-shadow: 2px 2px 10px rgba(0,0,0,0.5);">
#         İSTANBUL TRAFİK ANALİZİ
#     </h1>
#
# <p style="font-size: 22px; font-weight: 300; opacity: 0.9; margin-bottom: 30px; letter-spacing: 1px;">
#         12 Farklı Algoritma ile Akıllı Şehir Tahminleme Modeli
#     </p>
#
# <div style="background: rgba(255, 255, 255, 0.1); backdrop-filter: blur(5px); border: 1px solid rgba(255,255,255,0.2); padding: 25px; border-radius: 20px; margin: 0 auto; max-width: 750px;">
#         <p style="font-style: italic; font-size: 18px; line-height: 1.6; color: #e0e0e0;">
#             "İstanbul'un nabzı sadece caddelerinde değil, verilerinde atar. <br/>
#             Kaosu anlamlandırmak, bir şehri yönetmenin ilk adımıdır. <br/>
#             Biz bu kaosu <strong>matematik ve yapay zeka</strong> ile çözüyoruz." 🎯
#         </p>
#     </div>
#
# </div>
#
# <div style="height: 6px; background: linear-gradient(to right, #f093fb, #f5576c, #4facfe); border-radius: 10px; margin: 30px 0;"></div>
#
# <div style="background: #f8f9fa; border-left: 10px solid #1e3c72; padding: 30px; border-radius: 15px; box-shadow: 0 5px 15px rgba(0,0,0,0.05); margin-bottom: 40px;">
#
# <h2 style="color: #1e3c72; font-size: 28px; margin-top: 0; display: flex; align-items: center;">
#         📖 HİKAYEMİZ: KAOSTAN VERİYE YOLCULUK
#     </h2>
#
# <div style="margin-top: 20px; border-top: 1px solid #ddd; padding-top: 20px;">
#         <p style="font-size: 18px; color: #444; line-height: 1.8;">
#             <strong style="color: #d9534f;">🚨 Senaryo: Yarışa Karşı Zaman</strong><br>
#             Sabah 08:30, Kadıköy. Binlerce insan işine, okuluna yetişmeye çalışıyor. Mevcut sistemler sadece "şu anki" yoğunluğu söylerken, bizim ihtiyacımız olan <strong>30 dakika sonrasını bilmek!</strong>
#         </p>
#
# <p style="font-size: 18px; color: #444; line-height: 1.8; margin-top: 15px;">
#             <strong style="color: #5cb85c;">🎯 Çözüm: İleri Seviye Makine Öğrenmesi</strong><br>
#             İBB Açık Veri Portalı'ndan alınan devasa veri setini, regresyonun en güçlü 12 silahıyla işleyerek İstanbul'un trafik yoğunluğunu tahmin ediyoruz.
#         </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(90deg, #2c3e50 0%, #000000 100%); padding: 20px; border-radius: 15px; border-left: 8px solid #4facfe; margin: 20px 0;">
#     <h3 style="color: #4facfe; margin: 0; font-family: 'Segoe UI'; letter-spacing: 1px;">
#         🛠️ ADIM 1: Veri Cephaneliği ve Ham Veri Girişi
#     </h3>
# </div>
#
# <div style="padding: 15px; background-color: rgba(60, 127, 185, 0.05); border-radius: 10px; border: 1px dashed #4facfe; margin-bottom: 20px;">
#     <p style="color: #8f2e2e; font-size: 16px; line-height: 1.6;">
#         Analiz sürecimizin temel taşlarını oluşturan kütüphaneleri sisteme dahil ediyoruz.
#         Ardından, <b>İBB Açık Veri Portalı</b>'ndan elde ettiğimiz Ocak 2025 trafik yoğunluğu verisini
#         belleğe yükleyerek, üzerinde çalışmaya hazır hale getiriyoruz.
#     </p>
#
# <ul style="color: #753434; font-weight: 500;">
#         <li>🔍 <span style="color: #2a5298;">Veri Temizliği:</span> Sütun başlıklarındaki gereksiz boşluklar ve tırnak işaretleri otomatik olarak normalize edilmiştir.</li>
#         <li>📂 <span style="color: #2a5298;">Kaynak:</span> traffic_density_202501.csv</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #1a2a6c 0%, #b21f1f 50%, #fdbb2d 100%); padding: 25px; border-radius: 20px; box-shadow: 0 10px 30px rgba(0,0,0,0.2); margin: 25px 0;">
#     <h3 style="color: white; margin: 0; font-family: 'Segoe UI'; font-weight: 700; text-transform: uppercase; letter-spacing: 2px;">
#         ⚽ ADIM 2: Özellik Mühendisliği & Etkinlik Entegrasyonu
#     </h3>
# </div>
#
# <div style="background-color: #ffffff; border: 2px solid #b21f1f; padding: 25px; border-radius: 15px; margin-bottom: 25px; position: relative;">
#     <span style="position: absolute; top: -15px; right: 20px; background: #b21f1f; color: white; padding: 5px 15px; border-radius: 10px; font-weight: bold;">
#         Vektörel Tarama (Haversine)
#     </span>
#
# <p style="font-size: 17px; color: #333; line-height: 1.7;">
#         Trafiği etkileyen sadece saatler değil, şehirdeki <b>sosyal dinamiklerdir.</b> Bu aşamada, Ocak 2025 fikstürünü projemize dahil ederek maç günlerini ve stadyum çevresindeki yoğunluğu tespit ediyoruz.
#     </p>
#
# <div style="display: flex; gap: 20px; margin-top: 15px;">
#         <div style="flex: 1; background: #f8f9fa; padding: 15px; border-radius: 10px; border-left: 5px solid #1a2a6c;">
#             <b style="color: #1a2a6c;">📍 Uzamsal Analiz:</b> <br>
#             Stadyum merkezli <b>3.0 km</b> yarıçaptaki tüm koordinatlar taranmaktadır.
#         </div>
#         <div style="flex: 1; background: #f8f9fa; padding: 15px; border-radius: 10px; border-left: 5px solid #fdbb2d;">
#             <b style="color: #e67e22;">⏳ Zamansal Filtre:</b> <br>
#             Maç başlangıç ve bitiş saatleri aralığındaki veri noktaları etiketlenmektedir.
#         </div>
#     </div>
#
# <p style="margin-top: 20px; color: #666; font-style: italic;">
#         🚀 <b>Sonuç:</b> <code>is_match_zone</code> değişkeni ile modelimize maç trafiği anomalilerini tanıma yeteneği kazandırıldı.
#     </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #00b09b 0%, #96c93d 100%); padding: 20px; border-radius: 15px; box-shadow: 0 8px 20px rgba(0,0,0,0.1); margin: 25px 0;">
#     <h3 style="color: white; margin: 0; font-family: 'Segoe UI'; font-weight: 700; text-align: center; letter-spacing: 1px;">
#         🔍 ADIM 3: Veri Yapısının Doğrulanması ve İlk Bakış
#     </h3>
# </div>
#
# <div style="background: white; border-top: 5px solid #00b09b; padding: 20px; border-radius: 10px; margin-bottom: 20px; box-shadow: 0 4px 6px rgba(0,0,0,0.05);">
#     <p style="font-size: 16px; color: #444; line-height: 1.6;">
#         Zenginleştirilmiş veri setimizi kontrol masasına yatırıyoruz. Aşağıdaki tablo çıktıları, hem orijinal İBB verilerinin doğruluğunu hem de bizim tarafımızdan eklenen <b>zaman tabanlı (date_only)</b> ve <b>etkinlik tabanlı (is_match_zone)</b> yeni özniteliklerin başarıyla sisteme entegre edildiğini göstermektedir.
#     </p>
#
# <div style="display: flex; align-items: center; background: #f0fdf4; padding: 15px; border-radius: 8px; border: 1px solid #bbf7d0; margin-top: 10px;">
#         <span style="font-size: 24px; margin-right: 15px;">📊</span>
#         <span style="color: #166534; font-weight: 600;">
#             Önemli: Örnekleme (Sample) yöntemiyle verinin farklı

# %% [markdown]
# <div style="background: linear-gradient(135deg, #232526 0%, #414345 100%); padding: 25px; border-radius: 20px; box-shadow: 0 10px 25px rgba(0,0,0,0.2); margin: 25px 0; border-right: 8px solid #f093fb;">
#     <h3 style="color: #f093fb; margin: 0; font-family: 'Segoe UI'; font-weight: 700; letter-spacing: 1px;">
#         🛡️ ADIM 4: Veri Sağlığı ve Kalite Kontrolü
#     </h3>
# </div>
#
# <div style="background-color: #ffffff; border: 1px solid #e0e0e0; padding: 25px; border-radius: 15px; margin-bottom: 25px;">
#
# <div style="display: flex; gap: 20px;">
#         <div style="flex: 1; background: #fdf2f2; padding: 15px; border-radius: 12px; border-top: 4px solid #d9534f;">
#             <b style="color: #d9534f; font-size: 18px;">🚫 Eksik Veri Analizi</b><br>
#             <p style="color: #555; margin-top: 10px;">
#                 Tüm kolonlar taranmış ve <b>hiçbir eksik (null) değere rastlanmamıştır.</b> Veri seti, modelleme aşaması için %100 tamlık oranına sahiptir.
#             </p>
#         </div>
#
# <div style="flex: 1; background: #f0f7ff; padding: 15px; border-radius: 12px; border-top: 4px solid #0275d8;">
#             <b style="color: #0275d8; font-size: 18px;">📊 Veri Hacmi ve Tipleri</b><br>
#             <p style="color: #555; margin-top: 10px;">
#                 Toplam <b>1.7

# %% [markdown]
# <div style="background: linear-gradient(135deg, #FF512F 0%, #DD2476 100%); padding: 25px; border-radius: 20px; box-shadow: 0 12px 30px rgba(221, 36, 118, 0.3); margin: 25px 0;">
#     <h3 style="color: white; margin: 0; font-family: 'Segoe UI'; font-weight: 800; text-transform: uppercase; letter-spacing: 2px; text-align: center;">
#         🚨 ADIM 5: Aykırı Değer (Outlier) Röntgeni
#     </h3>
# </div>
#
# <div style="background-color: #fff5f5; border-left: 8px solid #DD2476; padding: 25px; border-radius: 15px; margin-bottom: 30px; box-shadow: 0 4px 15px rgba(0,0,0,0.05);">
#
# <p style="font-size: 17px; color: #444; line-height: 1.8;">
#         Makine öğrenmesi modelleri, <b>aykırı değerlere (outliers)</b> karşı oldukça hassastır. Hatalı sensör ölçümleri veya uç değerler, modelin öğrenme sürecini saptırabilir. Bu aşamada, verinin "röntgenini" çekerek temizlik öncesi durumu analiz ediyoruz.
#     </p>
#
# <div style="display: flex; gap: 20px; margin-top: 20px;">
#         <div style="flex: 1; background: white; padding: 15px; border-radius: 12px; border: 1px solid #ffccd5;">
#             <b style="color: #FF512F;">📊 Boxplot Analizi:</b> <br>
#             Kutu grafiği kullanarak verinin %50'lik merkez dilimini (IQR) belirliyor ve bu sınırların dışındaki noktaları potansiyel "gürültü" olarak işaretliyoruz.
#         </div>
#         <div style="flex: 1; background: white; padding: 15px; border-radius: 12px; border: 1px solid #ffccd5;">
#             <b style="color: #DD2476;">🎯 Hedef:</b> <br>
#             Ortalama hız ve araç sayısı kolonlarındaki mantıksız sapmaları tespit edip, daha kararlı bir tahmin modeli için zemin hazırlamak.
#         </div>
#     </div>
#
# <p style="margin-top: 20px; color: #880e4f; font-weight: 600; font-style: italic;">
#         ⚠️ Not: Grafiklerdeki "noktalar" ne kadar yoğunsa, veri temizliği o kadar kritik bir hal almaktadır.
#     </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #1D976C 0%, #93F9B9 100%); padding: 25px; border-radius: 20px; box-shadow: 0 10px 25px rgba(29, 151, 108, 0.2); margin: 25px 0;">
#     <h3 style="color: white; margin: 0; font-family: 'Segoe UI'; font-weight: 800; text-transform: uppercase; letter-spacing: 2px; text-align: center;">
#         🧹 ADIM 6: Veri Arındırma ve Optimizasyon
#     </h3>
# </div>
#
# <div style="background-color: #f0fff4; border: 2px solid #1D976C; padding: 25px; border-radius: 15px; margin-bottom: 25px; position: relative;">
#     <span style="position: absolute; top: -15px; left: 20px; background: #1D976C; color: white; padding: 5px 15px; border-radius: 10px; font-weight: bold;">
#         Sağlıklı Veri Seti Oluşturuldu
#     </span>
#
# <p style="font-size: 17px; color: #2d3748; line-height: 1.8;">
#         Ham veri setindeki gürültüyü temizlemek ve modelin tahmin yeteneğini maksimize etmek için üç aşamalı bir <b>mantıksal filtreleme</b> uyguluyoruz:
#     </p>
#
# <div style="margin-top: 15px;">
#         <div style="padding: 10px; border-bottom: 1px solid #c6f6d5;">
#             ✅ <b>Hız Sınırı Kontrolü:</b> İstanbul içi trafik akışına aykırı (150 km/h üstü) uç değerler temizlendi.
#         </div>
#         <div style="padding: 10px; border-bottom: 1px solid #c6f6d5;">
#             ✅ <b>Tutarlılık Denetimi:</b> Ortalama hızın, minimum ve maksimum hız sınırları arasında olması garanti altına alındı.
#         </div>
#         <div style

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb 0%, #2575fc 100%); padding: 30px; border-radius: 25px; box-shadow: 0 15px 35px rgba(37, 117, 252, 0.2); margin: 25px 0; border-bottom: 8px solid #6a11cb;">
#     <h3 style="color: white; margin: 0; font-family: 'Segoe UI'; font-weight: 800; text-transform: uppercase; letter-spacing: 2px; text-align: center;">
#         🧠 ADIM 7: İleri Seviye Özellik Mühendisliği (Feature Engineering)
#     </h3>
# </div>
#
# <div style="background-color: #f8faff; border-left: 10px solid #2575fc; padding: 25px; border-radius: 15px; margin-bottom: 30px; box-shadow: 0 5px 15px rgba(0,0,0,0.05);">
#
# <p style="font-size: 17px; color: #333; line-height: 1.8;">
#         Ham zaman verisini (Timestamp), trafiğin ritmini belirleyen <b>anlamlı sinyallere</b> dönüştürüyoruz. Sadece "saat" bilgisiyle yetinmeyip, şehrin sosyal takvimini algoritmalarımıza öğretiyoruz.
#     </p>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 15px; margin-top: 20px;">
#         <div style="background: white; padding: 15px; border-radius: 12px; border: 1px solid #d1d9e6;">
#             <b style="color: #6a11cb;">🔄 Döngüsel Zaman (Cyclic):</b> <br>
#             Saat verisini <code>Sin/Cos</code> fonksiyonları ile kodlayarak, 23:00 ile 00:00 arasındaki zamansal yakınlığı koruyoruz.
#         </div>
#         <div style="background: white; padding: 15px; border-radius: 12px; border: 1px solid #d1d9e6;">
#             <b style="color: #2575fc;">📅 Sosyal Takvim:</b> <br>
#             Hafta sonu, 1 Ocak Yılbaşı ve Sömestr Tatili (20-31 Ocak) gibi trafiği doğrudan etkileyen faktörleri vektörel olarak işaretliyoruz.
#         </div>
#     </div>
#
# <p style="margin-top: 20px; color: #4a5568; font-style: italic; font-weight: 600;">
#         🚀 <b>Neden Önemli?</b> Trafik kaotik görünse de döngüseldir. Bu adımla modelimize İstanbul'un "nefes alışını" öğrettik.
#     </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); padding: 25px; border-radius: 20px; box-shadow: 0 10px 25px rgba(56, 239, 125, 0.2); margin: 25px 0;">
#     <h3 style="color: white; margin: 0; font-family: 'Segoe UI'; font-weight: 800; text-transform: uppercase; letter-spacing: 2px; text-align: center;">
#         ✅ ADIM 8: Final Veri Seti ve Sınıf Dağılım Kontrolü
#     </h3>
# </div>
#
# <div style="background-color: #ffffff; border: 2px solid #11998e; padding: 25px; border-radius: 15px; margin-bottom: 25px; position: relative;">
#     <span style="position: absolute; top: -15px; right: 20px; background: #11998e; color: white; padding: 5px 15px; border-radius: 10px; font-weight: bold;">
#         Ready for Training
#     </span>
#
# <p style="font-size: 17px; color: #333; line-height: 1.8;">
#         Modelleme aşamasına geçmeden önceki <b>son duraktayız.</b> <code>df.sample(15)</code> çıktısı ile oluşturduğumuz tüm "Feature Engineering" kolonlarının (Hour_sin, is_weekend vb.) verideki tutarlılığını son kez gözlemliyoruz.
#     </p>
#
# <div style="margin-top: 20px; background: #f0fdf4; padding: 15px; border-radius: 10px; border-left: 5px solid #11998e;">
#         <b style="color: #11998e;">⚖️ Sınıf Dağılımı (Value Counts):</b> <br>
#         <code>is_match_zone</code> dağılımını kontrol ederek, maç trafiği olan örneklerin veri setindeki oranını analiz ediyoruz. Bu, modelimizin "anomali" sayılabilecek maç trafiklerini ne kadar veriyle öğreneceğini belirleyen kritik bir metriktir.
#     </div>
#
# <p style="margin-top: 20px; color: #1a535c; font-style: italic; font-weight: 500;">
#         🚀 <b>Durum Özeti:</b> Veri seti temizlendi, öznitelikler üretildi ve hedef değişkenler doğrulandı. Artık regresyonun 12 dev algoritmasını sahaya sürme vaktidir!
#     </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #141E30 0%, #243B55 100%); padding: 25px; border-radius: 20px; box-shadow: 0 10px 30px rgba(0,0,0,0.3); margin: 25px 0; border-left: 8px solid #ee0979;">
#     <h3 style="color: #ee0979; margin: 0; font-family: 'Segoe UI'; font-weight: 800; text-transform: uppercase; letter-spacing: 2px;">
#         🚀 ADIM 9: Altyapı Hazırlığı ve Ağır Silahların Kurulumu
#     </h3>
# </div>
#
# <div style="background-color: #ffffff; border: 1px solid #d1d9e6; padding: 25px; border-radius: 15px; margin-bottom: 25px;">
#
# <p style="font-size: 17px; color: #2c3e50; line-height: 1.8;">
#         Veri setimiz artık 15 farklı öznitelik (feature) ile modelleme için tam donanımlı hale geldi. Şimdi sıra, modern makine öğrenmesinin en güçlü algoritmalarından biri olan <b>XGBoost</b> (Extreme Gradient Boosting) kurulumunda.
#     </p>
#
# <div style="display: flex; align-items: center; background: #fff5f8; padding: 15px; border-radius: 10px; border: 1px solid #fed7e2; margin-top: 15px;">
#         <span style="font-size: 24px; margin-right: 15px;">⚡</span>
#         <span style="color: #9b2c2c; font-weight: 600;">
#             <b>XGBoost Entegrasyonu:</b> Karmaşık trafik verilerindeki doğrusal olmayan (non-linear) ilişkileri çözmek için bu güçlü kütüphaneyi çalışma ortamımıza dahil ediyoruz.
#         </span>
#     </div>
#
# <div style="margin-top: 20px; border-top: 1px solid #eee; padding-top: 15px;">
#         <b style="color: #243B55;">🔍 Öznitelik Listesi Doğrulandı:</b> <br>
#         <code style="color: #ee0979; background: #f8f9fa; padding: 2px 8px; border-radius: 5px;">LATITUDE</code>,
#         <code style="color: #ee0979; background: #f8f9fa; padding: 2px 8px; border-radius: 5px;">LONGITUDE</code>,
#         <code style="color: #ee0979; background: #f8f9fa; padding: 2px 8px; border-radius: 5px;">is_match_zone</code>,
#         <code style="color: #ee0979; background: #f8f9fa; padding: 2px 8px; border-radius: 5px;">hour_sin/cos</code> ...
#     </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #8E2DE2 0%, #4A00E0 100%); padding: 35px; border-radius: 25px; box-shadow: 0 20px 40px rgba(74, 0, 224, 0.3); margin: 25px 0; border-bottom: 10px solid #310094;">
#     <h1 style="color: white; margin: 0; font-family: 'Segoe UI'; font-weight: 900; text-transform: uppercase; letter-spacing: 3px; text-align: center;">
#         🏁 AŞAMA 4: BÜYÜK ALGORİTMA YARIŞI (BENCHMARK)
#     </h1>
#     <p style="color: rgba(255,255,255,0.8); text-align: center; font-size: 18px; margin-top: 10px;">
#         12 Regresyon Modeli | Tek Veri Seti | Tek Şampiyon
#     </p>
# </div>
#
# <div style="background-color: #ffffff; border: 2px solid #4A00E0; padding: 25px; border-radius: 15px; margin-bottom: 30px;">
#
# <div style="display: flex; align-items: center; background: #f3f0ff; padding: 15px; border-radius: 12px; margin-bottom: 20px; border-left: 6px solid #8E2DE2;">
#         <span style="font-size: 28px; margin-right: 15px;">⚖️</span>
#         <p style="margin: 0; color: #310094; font-size: 16px; font-weight: 600;">
#             <b>Stratejik Hazırlık:</b> Veri seti, modellerin birbirini ezmemesi için <code>StandardScaler</code> ile normalize edildi ve donanım verimliliği için %5'lik temsilci (sample) grup üzerinden ön testler başlatıldı.
#         </p>
#     </div>
#
# <h3 style="color: #4A00E0; border-bottom: 2px solid #eee; padding-bottom: 10px;">🛡️ Sahadaki Takımlar</h3>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin-top: 15px;">
#         <div style="background: #f8f9fa; padding: 15px; border-radius: 12px; border: 1px solid #e0e0e0; box-shadow: 2px 2px 5px rgba(0,0,0,0.02);">
#             <b style="color: #8E2DE2;">📉 Lineer Modeller</b><br>
#             <small style="color: #666; font-size: 13px;">Linear Regression, Ridge, Lasso, ElasticNet</small>
#         </div>
#
# <div style="background: #f8f9fa; padding: 15px; border-radius: 12px; border: 1px solid #e0e0e0; box-shadow: 2px 2px 5px rgba(0,0,0,0.02);">
#             <b style="color: #4A00E0;">🌳 Ağaç & Komşuluk</b><br>
#             <small style="color: #666; font-size: 13px;">Decision Tree, KNN, SVR (RBF Kernel)</small>
#         </div>
#
# <div style="background: #f8f9fa; padding: 15px; border-radius: 12px; border: 1px solid #e0e0e0; box-shadow: 2px 2px 5px rgba(0,0,0,0.02);">
#             <b style="color: #ee0979;">🚀 Ensemble (Devler)</b><br>
#             <small style="color: #666; font-size: 13px;">Random Forest, Extra Trees, XGBoost, LightGBM</small>
#         </div>
#     </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #f5af19 0%, #f12711 100%); padding: 35px; border-radius: 25px; box-shadow: 0 20px 45px rgba(241, 39, 17, 0.4); margin: 25px 0; border: 5px solid #fff;">
#     <h1 style="color: white; margin: 0; font-family: 'Segoe UI'; font-weight: 900; text-transform: uppercase; letter-spacing: 3px; text-align: center; text-shadow: 2px 2px 10px rgba(0,0,0,0.3);">
#         🏆 ŞAMPİYON: EXTRA TREES REGRESSOR
#     </h1>
#     <p style="color: white; text-align: center; font-size: 20px; font-weight: 600; margin-top: 10px; opacity: 0.9;">
#         İstanbul Trafiğini %91.3 İsabetle Tahmin Ediyoruz!
#     </p>
# </div>
#
# <div style="background-color: #ffffff; border-top: 10px solid #f5af19; padding: 30px; border-radius: 15px; margin-bottom: 30px; box-shadow: 0 10px 20px rgba(0,0,0,0.05);">
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; text-align: center; margin-bottom: 25px;">
#         <div style="background: #fff8e1; padding: 20px; border-radius: 15px; border: 1px solid #ffecb3;">
#             <span style="font-size: 14px; color: #ffa000; font-weight: 800; text-transform: uppercase;">Başarı Oranı (R²)</span><br>
#             <span style="font-size: 36px; color: #f5af19; font-weight: 900;">0.913</span>
#         </div>
#         <div style="background: #ffebee; padding: 20px; border-radius: 15px; border: 1px solid #ffcdd2;">
#             <span style="font-size: 14px; color: #d32f2f; font-weight: 800; text-transform: uppercase;">Hata Payı (RMSE)</span><br>
#             <span style="font-size: 36px; color: #f12711; font-weight: 900;">7.196</span>
#         </div>
#     </div>
#
# <h3 style="color: #333; border-bottom: 2px solid #f5af19; padding-bottom: 10px;">📊 Model Performans Analizi</h3>
#     <p style="font-size: 17px; color: #444; line-height: 1.8; margin-top: 15px;">
#         12 farklı algoritma arasından sıyrılan <b>Extra Trees</b>, İstanbul'un karmaşık trafik yapısını en iyi simüle eden model olmuştur.
#         Özellikle <b>Linear Regression (%11.9)</b> gibi temel modellerin düşük performansı, trafik verisinin doğrusal olmayan (non-linear) ve karmaşık ilişkiler barındırdığını kanıtlamaktadır.
#     </p>
#
# <ul style="color: #555; font-size: 16px; line-height: 2;">
#         <li>✨ <b>Ensemble Gücü:</b> Ağaç tabanlı modeller (Random Forest, Extra Trees) en yüksek kararlılığı sergiledi.</li>
#         <li>🚨 <b>Anomali Yakalama:</b> Maç bölgeleri ve tatil günleri gibi eklediğimiz özellikler, hata payını minimize etti.</li>
#     </ul>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #000000 0%, #434343 100%); padding: 40px; border-radius: 30px; box-shadow: 0 25px 50px rgba(0,0,0,0.4); margin: 30px 0; border: 2px solid #f5af19; text-align: center;">
#     <h1 style="color: #f5af19; margin: 0; font-family: 'Segoe UI'; font-weight: 900; text-transform: uppercase; letter-spacing: 5px; text-shadow: 0 0 15px rgba(245, 175, 25, 0.5);">
#         🔥 BÜYÜK FİNAL: %100 VERİ KAPASİTESİ
#     </h1>
#     <p style="color: #ffffff; font-size: 20px; font-weight: 300; margin-top: 15px; letter-spacing: 1px; opacity: 0.8;">
#         1.6 Milyon Satır | Tam Ölçekli Eğitim | Maksimum Performans
#     </p>
# </div>
#
# <div style="background-color: #ffffff; border-left: 10px solid #000000; padding: 30px; border-radius: 15px; margin-bottom: 35px; box-shadow: 0 10px 25px rgba(0,0,0,0.05);">
#
# <div style="display: flex; align-items: center; background: #fff9db; padding: 20px; border-radius: 12px; border: 1px solid #f5af19; margin-bottom: 25px;">
#         <span style="font-size: 32px; margin-right: 20px;">🛡️</span>
#         <p style="margin: 0; color: #856404; font-size: 17px; font-weight: 600; line-height: 1.6;">
#             <b>Zincirler Kırıldı:</b> Örneklem (Sampling) aşaması başarıyla tamamlandı. Artık modellerimiz İstanbul'un tüm trafik paternlerini öğrenmek için <b>%100 veri seti</b> ile savaşa giriyor.
#         </p>
#     </div>
#
# <h3 style="color: #333; margin-bottom: 20px;">🏆 Arena: En İyi 3 Aday</h3>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px;">
#         <div style="background: #f8f9fa; padding: 15px; border-radius: 12px; border: 2px solid #f5af19; text-align: center;">
#             <b style="color: #f5af19; font-size: 18px;">Extra Trees</b><br>
#             <small style="color: #666;">Yüksek Varyans Yönetimi</small>
#         </div>
#         <div style="background: #f8f9fa; padding: 15px; border-radius: 12px; border: 1px solid #ddd; text-align: center;">
#             <b style="color: #2575fc; font-size: 18px;">Random Forest</b><br>
#             <small style="color: #666;">Kararlı Tahmin Gücü</small>
#         </div>
#         <div style="background: #f8f9fa; padding: 15px; border-radius: 12px; border: 1px solid #ddd; text-align: center;">
#             <b style="color: #ee0979; font-size: 18px;">XGBoost</b><br>
#             <small style="color: #666;">Gradyan Artırma Hızı</small>
#         </div>
# </div>
#
# <p style="margin-top: 25px; color: #555; line-height: 1.8; font-style: italic;">
#         🚀 <b>Donanım Notu:</b> İşlemci tüm çekirdekleri (n_jobs=-1) paralel olarak kullanılmaktadır. Eğitim süreci verinin devasa boyutundan dolayı donanım gücüne bağlı olarak 10-30 dakika arasında optimize edilecektir.
#     </p>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%); padding: 45px; border-radius: 30px; box-shadow: 0 25px 60px rgba(30, 60, 114, 0.4); margin: 30px 0; border: 4px solid #ffffff; text-align: center;">
#     <div style="font-size: 70px; margin-bottom: 20px;">👑</div>
#     <h1 style="color: #ffffff; margin: 0; font-family: 'Segoe UI'; font-weight: 900; text-transform: uppercase; letter-spacing: 5px; text-shadow: 2px 4px 15px rgba(0,0,0,0.3);">
#         MUTLAK ŞAMPİYON: RANDOM FOREST
#     </h1>
#     <p style="color: rgba(255,255,255,0.9); font-size: 22px; font-weight: 300; margin-top: 15px; letter-spacing: 2px;">
#         1.6 Milyon Veride %94.7 Başarı ile İstanbul'un Trafik Kodu Çözüldü!
#     </p>
# </div>
#
# <div style="background-color: #ffffff; border-top: 12px solid #1e3c72; padding: 35px; border-radius: 20px; margin-bottom: 40px; box-shadow: 0 15px 35px rgba(0,0,0,0.08);">
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 30px; margin-bottom: 35px;">
#         <div style="background: #eef2f7; padding: 30px; border-radius: 25px; border: 1px solid #d1d9e6; text-align: center;">
#             <span style="font-size: 15px; color: #1e3c72; font-weight: 800; text-transform: uppercase; letter-spacing: 1px;">Model Skoru (R²)</span><br>
#             <span style="font-size: 48px; color: #1e3c72; font-weight: 900;">0.947</span>
#             <p style="margin-top: 10px; color: #555; font-size: 15px;">Verideki karmaşıklığın %94.7'si hatasız öngörüldü.</p>
#         </div>
#         <div style="background: #fff5f5; padding: 30px; border-radius: 25px; border: 1px solid #fed7d7; text-align: center;">
#             <span style="font-size: 15px; color: #c53030; font-weight: 800; text-transform: uppercase; letter-spacing: 1px;">Hata Payı (RMSE)</span><br>
#             <span style="font-size: 48px; color: #c53030; font-weight: 900;">5.581</span>
#             <p style="margin-top: 10px; color: #555; font-size: 15px;">Ortalama tahmin sapması sadece 5.5 km/h seviyesindedir.</p>
#         </div>
#     </div>
#
# <div style="background: #f8fafc; border-left: 10px solid #1e3c72; padding: 30px; border-radius: 15px;">
#         <h4 style="color: #1e3c72; margin-top: 0; font-size: 20px;">📑 Final Değerlendirmesi</h4>
#         <p style="font-size: 17px; color: #334155; line-height: 1.8;">
#             Test edilen 12 algoritma içerisinde <b>Random Forest</b>, devasa veri hacminde (Big Data) en kararlı (stable) sonuçları üreten model olmuştur.
#             Maç günleri, sömestr tatilleri ve coğrafi koordinatlar gibi eklediğimiz öznitelikleri en verimli şekilde işleyerek, İstanbul trafiğindeki ani değişimleri yakalamada üstünlük sağlamıştır.
#             Özellikle doğrusal olmayan (non-linear) örüntülerde sergilediği bu başarı, projenin temel hedefine ulaştığını kanıtlamaktadır.
#         </p>
#     </div>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #f83600 0%, #f9d423 100%); padding: 25px; border-radius: 20px; box-shadow: 0 15px 35px rgba(248, 54, 0, 0.2); margin: 25px 0; border-right: 10px solid #f83600;">
#     <h3 style="color: white; margin: 0; font-family: 'Segoe UI'; font-weight: 800; text-transform: uppercase; letter-spacing: 2px; text-align: center;">
#         🧠 ADIM 10: Modelin Karar Mekanizması (X-Ray)
#     </h3>
# </div>
#
# <div style="background-color: #fffaf0; border: 2px solid #f83600; padding: 25px; border-radius: 15px; margin-bottom: 30px;">
#
# <p style="font-size: 17px; color: #333; line-height: 1.8;">
#         Şampiyon modelimiz sadece tahmin yapmıyor, aynı zamanda İstanbul trafiğinin şifrelerini çözüyor. Bu aşamada, modelin karar verirken hangi değişkenlere (konum, saat, maç durumu vb.) <b>ne kadar ağırlık verdiğini</b> analiz ediyoruz.
#     </p>
#
# <div style="display: flex; gap: 20px; margin-top: 20px;">
#         <div style="flex: 1; background: white; padding: 15px; border-radius: 12px; border: 1px dashed #f83600;">
#             <b style="color: #f83600;">📌 Feature Importance:</b> <br>
#             Modelin "matematiksel ağırlık merkezini" buluyoruz. Hangi özellik (feature) tahmin başarısını (R²) en çok sırtlıyor?
#         </div>
#         <div style="flex: 1; background: white; padding: 15px; border-radius: 12px; border: 1px dashed #f83600;">
#             <b style="color: #e67e22;">🗺️ Coğrafi & Zamansal Etki:</b> <br>
#             Konum verilerinin (Lat/Lon) ve ürettiğimiz döngüsel saatlerin (Sin/Cos) trafik yoğunluğu üzerindeki etkisini bilimsel olarak kanıtlıyoruz.
#         </div>
#     </div>
#
# <p style="margin-top: 25px; color: #c0392b; font-weight: 600; text-align: center;">
#         ⬇️ Aşağıdaki grafik, modelin İstanbul trafiğini okurken kullandığı "Öncelik Listesi"ni temsil etmektedir.
#     </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #232526 0%, #414345 100%); padding: 30px; border-radius: 25px; box-shadow: 0 15px 35px rgba(0,0,0,0.3); margin: 25px 0; border-left: 12px solid #2ecc71;">
#     <h3 style="color: #2ecc71; margin: 0; font-family: 'Segoe UI'; font-weight: 800; text-transform: uppercase; letter-spacing: 2px;">
#         💾 ADIM 11: Model Paketleme ve Canlı Kullanıma Hazırlık
#     </h3>
# </div>
#
# <div style="background-color: #f8f9fa; border: 2px solid #2ecc71; padding: 25px; border-radius: 15px; margin-bottom: 30px;">
#
# <p style="font-size: 17px; color: #333; line-height: 1.8;">
#         Eğitilen şampiyon model (Random Forest) ve verileri standardize eden ölçekleyici (Scaler), <b>Joblib</b> kütüphanesi kullanılarak sıkıştırılmış formatta diske kaydedilmiştir. Bu sayede modelimiz artık statik bir kod bloğu olmaktan çıkıp, <b>canlı sistemlere entegre edilebilir</b> bir ürün haline gelmiştir.
#     </p>
#
# <div style="display: flex; gap: 20px; margin-top: 15px;">
#         <div style="flex: 1; background: white; padding: 15px; border-radius: 12px; border: 1px solid #2ecc71;">
#             <b style="color: #27ae60;">📦 Model Export:</b> <br>
#             <code>istanbul_traffic_rf_model.pkl</code> (Sıkıştırılmış)
#         </div>
#         <div style="flex: 1; background: white; padding: 15px; border-radius: 12px; border: 1px solid #27ae60;">
#             <b style="color: #27ae60;">📏 Scaler Export:</b> <br>
#             <code>traffic_scaler.pkl</code>
#         </div>
#     </div>
# </div>
#
# <div style="height: 5px; background: linear-gradient(to right, #1e3c72, #2ecc71, #f5af19); border-radius: 10px; margin: 40px 0;"></div>
#
# <div style="background: linear-gradient(135deg, #1e3c72 0%, #2a5298 100%); padding: 50px; border-radius: 30px; box-shadow: 0 30px 60px rgba(30,60,114,0.5); text-align: center; border: 2px solid rgba(255,255,255,0.1);">
#
# <div style="text-align: center; padding: 40px; font-family: 'Segoe UI', sans-serif;">
#
# <div style="font-size: 80px; margin-bottom: 20px;">🏁</div>
#
# <h1 style="color: white; font-weight: 900; letter-spacing: 5px; text-transform: uppercase; margin-bottom: 20px;">
#         PROJE TAMAMLANDI
#     </h1>
#
# <div style="max-width: 700px; margin: 0 auto; background: rgba(255,255,255,0.1); backdrop-filter: blur(10px); padding: 30px; border-radius: 20px; border: 1px solid rgba(255,255,255,0.2);">
#         <p style="color: #e0e0e0; font-size: 18px; line-height: 1.8; font-style: italic;">
#             "Ham veriden akıllı tahminlere uzanan bu yolculukta; 1.6 milyon satırı işledik, 12 farklı algoritmayı yarıştırdık ve İstanbul'un trafik yoğunluğunu %94.7 isabetle tahmin etmeyi başardık."
#         </p>
#     </div>
#
# <div style="margin-top: 40px;">
#         <p style="color: #f5af19; font-size: 22px; font-weight: 700; letter-spacing: 1px;">
#             💻 Geliştiren:
#         </p>
#         <p style="color: rgba(255,255,255,0.6); font-size: 14px; margin-top: 10px;">
#             Veri Bilimi ve Makine Öğrenmesi | Mart 2026
#         </p>
#     </div>
#
# </div>
# <div style="font-size
